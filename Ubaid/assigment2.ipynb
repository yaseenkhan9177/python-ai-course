# %%
import pandas as pd
import numpy as np

data = ([
    [1,2,3,4],
    [5,4,3,4],
    [2,3,4,5],
    [3,1,2,5],
    [2,1,5,7],
])
df = pd.DataFrame(data, columns= (['A','B','C','D']))
print (df)
# Out:
#    A  B  C  D
# 0  1  2  3  4
# 1  5  4  3  4
# 2  2  3  4  5
# 3  3  1  2  5
# 4  2  1  5  7

# %%
pd.DataFrame(df)
# Out:
#    A  B  C  D
# 0  1  2  3  4
# 1  5  4  3  4
# 2  2  3  4  5
# 3  3  1  2  5
# 4  2  1  5  7

# %%
df.head(2)
# Out:
#    0  1  2  3
# 0  1  2  3  4
# 1  5  4  3  4

# %%
df.head(3)
# Out:
#    A  B  C  D
# 0  1  2  3  4
# 1  5  4  3  4
# 2  2  3  4  5

# %%
df.tail(2)
# Out:
#    A  B  C  D
# 3  3  1  2  5
# 4  2  1  5  7

# %%
df.tail(3)
# Out:
#    A  B  C  D
# 2  2  3  4  5
# 3  3  1  2  5
# 4  2  1  5  7

# %%
df.iloc[0]
# Out:
# A    1
# B    2
# C    3
# D    4
# Name: 0, dtype: int64

# %%
df.iloc[3]
# Out:
# A    3
# B    1
# C    2
# D    5
# Name: 3, dtype: int64

# %%
df.iloc[0:5]
# Out:
#    A  B  C  D
# 0  1  2  3  4
# 1  5  4  3  4
# 2  2  3  4  5
# 3  3  1  2  5
# 4  2  1  5  7

# %%
df.iloc[0:3]
# Out:
#    A  B  C  D
# 0  1  2  3  4
# 1  5  4  3  4
# 2  2  3  4  5

# %%
df['A']
# Out:
# 0    1
# 1    5
# 2    2
# 3    3
# 4    2
# Name: A, dtype: int64

# %%
df.iloc[0:4, 0:2]
# Out:
#    A  B
# 0  1  2
# 1  5  4
# 2  2  3
# 3  3  1

# %%
arr = np.array([[3,1,5],[1,3,2],[4,2,6],[2,5,1]])
np.sort(arr)
# Out:
# array([[1, 3, 5],
#        [1, 2, 3],
#        [2, 4, 6],
#        [1, 2, 5]])

# %%
print(np.sort(arr,axis=0))
# Out:
# [[1 1 1]
#  [2 2 2]
#  [3 3 5]
#  [4 5 6]]

# %%
print(np.sort(arr,axis=1))
# Out:
# [[1 1 1]
#  [2 2 2]
#  [3 3 5]
#  [4 5 6]]
